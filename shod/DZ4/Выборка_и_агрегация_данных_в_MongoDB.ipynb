# %% [markdown]
# # Выборка и агрегация данных в MongoDB
#
# ###Цель домашней работы
#
# Закрепить на практике основные приемы работы с СУБД MongoDB, включая выборку, сортировку, объединение, агрегацию данных и передачу результатов выборки в программу на Python в целях аналитики и дальнейшей обработки.

# %% [markdown]
# ### Формулировка задания
#
# В этом задании вам предстоит выполнить несколько запросов к базе данных для получения выборок по условиям, а также воспользоваться фреймворком агрегации MongoDB для построения конвейера обработки данных.
#
# Максимальное количество баллов за выполнение домашней работы: 10.

# %% [markdown]
# ##Что нужно использовать в работе над заданием
#
# I. MongoDB:
#
# 1. Зарегистрируйтесь в сервисе MongoDB Atlas: https://www.mongodb.com/atlas/database.
# 1. Создайте кластер уровня M0 (это бесплатно).
# 1. Добавьте в кластер тестовую базу данных `sample_mflix`, используя опцию Load Sample Dataset.
#
# В качестве альтернативы вы можете установить MongoDB на свой локальный компьютер и импортировать необходимые датасеты в свою СУБД, загрузив их по ссылке: https://github.com/neelabalan/mongodb-sample-dataset/tree/main/sample_mflix. Для этого подключитесь к своему серверу через Compass, создайте новую БД, создайте для каждого датасета коллекцию и щелкните «Add data» → «Import JSON or CSV file».
#
# II. MongoDB Compass — в качестве вспомогательного инструмента для конструирования запросов и агрегаций.
#
# III. Python и библиотека pymongo. Работа ведется в Jupyter Notebook или Google Colaboratory. Рекомендуется использовать версию Python 3.12.

# %% [markdown]
# ##Ожидаемые результаты
#
# Результаты работы необходимо оформить в виде ноутбука Jupyter. Можно загрузить файл в LMS либо поделиться ссылкой на Google Colaboratory.

# %% [markdown]
# ##Место где нужно выполнить задание

# %%
#Начать выполнение задания тут

# %%
# !pip install pymongo

import pymongo

client = pymongo.MongoClient("mongodb+srv://nekita473:test1234@cluster0.tbhwv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
print(client.list_database_names())  # Вывести список БД для проверки подключения
# Out:
# ['sample_mflix', 'admin', 'local']

# %% [markdown]
# ### Упражнение 1. Запросы на выборку

# %% [markdown]
# Цель этого упражнения — закрепить навык выполнения запросов на выборку. Все запросы выполняются на базе `sample_mflix` с данными о кинофильмах.

# %% [markdown]
# #### Задача 1.1 — **1 балл**

# %% [markdown]
# Выведите из коллекции `theaters` документы о кинотеатрах в городе Florence, штат KY.
#
# Для справки:
#
# * Обратите внимание на то, что информация об адресе кинотеатров хранится во вложенных документах. Для доступа к полям вложенных документов следует использовать точку: `родительский_документ.вложенный_документ.поле`.
# * В случае затруднений с написанием логического условия обращайтесь к сопоставлению синтаксиса SQL и Mongo: https://www.mongodb.com/docs/manual/reference/sql-comparison/.
# * Если вы предпочитаете сперва выполнять запросы в Compass, из этого приложения можно выгружать код готового запроса на Python (кнопка с символом `</>`).

# %%
# Ваш код здесь
db = client.sample_mflix

list(db['theaters'].find({'location.address.city': 'Florence'}))
# Out:
# [{'_id': ObjectId('59a47287cfa9a3a73e51e893'),
#   'theaterId': 161,
#   'location': {'address': {'street1': '100 Meijer Dr.',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.636383, 39.014843]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ea02'),
#   'theaterId': 2823,
#   'location': {'address': {'street1': '2823 Florence Mall',
#     'street2': '#2148',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.6499595, 38.9967246]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ead9'),
#   'theaterId': 348,
#   'location': {'address': {'street1': '398 Cox Creek Parkway',
#     'city': 'Florence',
#     'state': 'AL',
#     'zipcode': '35630'},
#    'geo': {'type': 'Point', 'coordinates': [-87.637985, 34.842548]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ecca'),
#   'theaterId': 826,
#   'location': {'address': {'street1': '2701 David H Mcleod Blvd',
#     'city': 'Florence',
#     'state': 'SC',
#     'zipcode': '29501'},
#    'geo': {'type': 'Point', 'coordinates': [-79.828201, 34.191662]}}}]

# %% [markdown]
# #### Задача 1.2 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `comments`, выведите _один_ комментарий (значение поля `text`) пользователя по имени Doreah.

# %%
# Ваш код здесь

list(db['comments'].find({'name': 'Doreah'}))[0]['text']
# Out:
# 'Porro explicabo cumque vitae sint quia quis. Consequuntur voluptatibus optio maxime ratione temporibus incidunt minus architecto.'

# %% [markdown]
# #### Задача 1.3 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `movies`, выведите количество документов, в которых в качестве первого жанра фильма (поле `genres`) указано значение «Horror».
#
# Для справки:
#
# 1. Обратите внимание, что поле `genres` представляет собой массив (индексация массивов начинается с нуля).
# 1. При работе в MongoDB Shell для подсчета количества документов в курсоре можно использовать метод `count()`, однако он был удален в последних версиях библиотеки pymongo. В случае затруднений с использованием функций Mongo можно использовать для подсчета документов средства Python.

# %%
# Ваш код здесь

len([x for x in list(db['movies'].find({'genres': 'Horror'})) if x['genres'][0] == 'Horror'])
# Out:
# 700

# %% [markdown]
# #### Задача 1.4 — **2 балла**

# %% [markdown]
# Выведите из коллекции `movies` документы о фильмах, которые в качестве первого жанра определены как «Film-Noir» либо «Horror» и были выпущены в период с 1940 по 1949 гг. (включительно).

# %%
# Ваш код здесь

list(db['movies'].find({'year': {'$gt': 1940, '$lt': 1949}}))
# Out:
# [{'_id': ObjectId('573a1393f29313caabcdc364'),
#   'plot': 'Illiterate peasant Juan Gallardo rises meteorically to fame and fortune in the bullfight arena only to sow the seeds of his own fall.',
#   'genres': ['Drama', 'Sport'],
#   'runtime': 125,
#   'rated': 'APPROVED',
#   'cast': ['Tyrone Power', 'Linda Darnell', 'Rita Hayworth', 'Alla Nazimova'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZDU4YmIyMDUtYjA5NC00ODYyLWJmNTItOTZlYTZlNmFjNGVkL2ltYWdlXkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Blood and Sand',
#   'fullplot': 'Bullfighter Juan Gallardo falls for socialite Dona Sol, turning from the faithful Carmen who nevertheless stands by her man as he continues to face real danger in the bullring.',
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 5, 30, 0, 0),
#   'directors': ['Rouben Mamoulian'],
#   'writers': ['Vicente Blasco Ibèèez (based on the novel by)',
#    'Jo Swerling (screenplay)'],
#   'awards': {'wins': 0,
#    'nominations': 2,
#    'text': 'Won 1 Oscar. Another 1 nomination.'},
#   'lastupdated': '2015-09-05 00:27:47.423000000',
#   'year': 1941,
#   'imdb': {'rating': 7.0, 'votes': 1417, 'id': 33405},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 611, 'meter': 67},
#    'dvd': datetime.datetime(2007, 5, 1, 0, 0),
#    'critic': {'rating': 7.2, 'numReviews': 6, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 19, 7, 49),
#    'rotten': 0,
#    'production': '20th Century Fox',
#    'fresh': 6}},
#  {'_id': ObjectId('573a1393f29313caabcdc370'),
#   'plot': 'An atheist accidentally shoots his Baptist wife. She dies and goes to a crossroads, where the devil tries to lead her astray.',
#   'genres': ['Drama', 'Fantasy'],
#   'runtime': 57,
#   'rated': 'APPROVED',
#   'title': 'The Blood of Jesus',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQyNzc4MjkwMl5BMl5BanBnXkFtZTcwNjM5NTAyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': "In the rural south of the United States, a godly young woman is accidently wounded by her unchurched husband. She succumbs to the injuries, whereupon a good angel bids her to journey with him to the Crossroads of Life. Before she can travel far, the devil lures her with the temptations of juke joints and the city. Can she regain the straight and narrow before it's too late? And what is to become of those she left behind?",
#   'languages': ['English'],
#   'cast': ['Cathryn Caviness',
#    'Spencer Williams',
#    'Juanita Riley',
#    'Reather Hardeman'],
#   'directors': ['Spencer Williams'],
#   'writers': ['Spencer Williams'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-04-09 01:08:27.730000000',
#   'year': 1941,
#   'imdb': {'rating': 5.4, 'votes': 228, 'id': 33406},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 2.5, 'numReviews': 11},
#    'dvd': datetime.datetime(1993, 6, 15, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 25, 18, 50, 6)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc371'),
#   'plot': 'Edna marries Texan Sam Gladney, operator of a wheat mill. Edna discovers by chance how the law treats children who are without parents and decides to do something about it. She opens a home...',
#   'genres': ['Biography', 'Drama', 'Romance'],
#   'runtime': 99,
#   'rated': 'APPROVED',
#   'cast': ['Greer Garson', 'Walter Pidgeon', 'Felix Bressart', 'Marsha Hunt'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZDZiZDBmOWYtYTU0Mi00ZTQ5LWE3NDAtZDY5ODFlNzVmYjNmXkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Blossoms in the Dust',
#   'fullplot': 'Edna marries Texan Sam Gladney, operator of a wheat mill. Edna discovers by chance how the law treats children who are without parents and decides to do something about it. She opens a home for foundlings and orphans and begins to place children in good homes, despite the opposition of "conservative" citizens, who would condemn illegitimate children for being born out of wedlock. Eventually Edna leads a fight in the Texas legislature to remove the stigma of illegitimacy from birth records in that state, while continuing to be an advocate for homeless children.',
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 7, 25, 0, 0),
#   'directors': ['Mervyn LeRoy'],
#   'writers': ['Anita Loos (screen play)', 'Ralph Wheelwright (story)'],
#   'awards': {'wins': 0,
#    'nominations': 4,
#    'text': 'Won 1 Oscar. Another 3 nominations.'},
#   'lastupdated': '2015-06-29 01:08:22.717000000',
#   'year': 1941,
#   'imdb': {'rating': 7.0, 'votes': 1085, 'id': 33407},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 357, 'meter': 72},
#    'dvd': datetime.datetime(2011, 8, 2, 0, 0),
#    'critic': {'rating': 5.3, 'numReviews': 8, 'meter': 25},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 19, 7, 52),
#    'rotten': 6,
#    'production': 'WARNER BROTHERS PICTURES',
#    'fresh': 2}},
#  {'_id': ObjectId('573a1393f29313caabcdc3a3'),
#   'plot': 'Following the death of a publishing tycoon, news reporters scramble to discover the meaning of his final utterance.',
#   'genres': ['Drama', 'Mystery'],
#   'runtime': 119,
#   'rated': 'APPROVED',
#   'cast': ['Joseph Cotten',
#    'Dorothy Comingore',
#    'Agnes Moorehead',
#    'Ruth Warrick'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYjBiOTYxZWItMzdiZi00NjlkLWIzZTYtYmFhZjhiMTljOTdkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Citizen Kane',
#   'fullplot': 'A group of reporters are trying to decipher the last word ever spoken by Charles Foster Kane, the millionaire newspaper tycoon: "Rosebud." The film begins with a news reel detailing Kane\'s life for the masses, and then from there, we are shown flashbacks from Kane\'s life. As the reporters investigate further, the viewers see a display of a fascinating man\'s rise to fame, and how he eventually fell off the top of the world.',
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 9, 5, 0, 0),
#   'directors': ['Orson Welles'],
#   'writers': ['Herman J. Mankiewicz (original screen play)',
#    'Orson Welles (original screen play)'],
#   'awards': {'wins': 9,
#    'nominations': 10,
#    'text': 'Won 1 Oscar. Another 8 wins & 10 nominations.'},
#   'lastupdated': '2015-08-31 00:18:44.123000000',
#   'year': 1941,
#   'imdb': {'rating': 8.4, 'votes': 271165, 'id': 33467},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 154844, 'meter': 90},
#    'dvd': datetime.datetime(2001, 9, 25, 0, 0),
#    'critic': {'rating': 9.4, 'numReviews': 69, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 12, 18, 12, 22),
#    'consensus': "Orson Welles's epic tale of a publishing tycoon's rise and fall is entertaining, poignant, and inventive in its storytelling, earning its reputation as a landmark achievement in film.",
#    'rotten': 0,
#    'production': 'RKO Radio Pictures',
#    'fresh': 69}},
#  {'_id': ObjectId('573a1393f29313caabcdc3f7'),
#   'plot': 'A nineteenth-century New Hampshire farmer who makes a compact with Satan for economic success enlists Daniel Webster to extract him from his contract.',
#   'genres': ['Comedy', 'Drama', 'Fantasy'],
#   'runtime': 107,
#   'rated': 'APPROVED',
#   'cast': ['Edward Arnold', 'Walter Huston', 'Jane Darwell', 'Simone Simon'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMzRjNzk3NDUtNDU1Mi00NDA1LWI2Y2YtZjk0ZmJiZjZkN2FkL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Devil and Daniel Webster',
#   'fullplot': 'A down-on-his-luck farmer makes a deal with the devil for seven years of prosperity. When Mr. Scratch comes to collect, orator and hero of the common man Daniel Webster comes to the rescue.',
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 10, 29, 0, 0),
#   'directors': ['William Dieterle'],
#   'writers': ['Stephen Vincent Benet (story)',
#    'Dan Totheroh (screenplay)',
#    'Stephen Vincent Benet (screenplay)'],
#   'awards': {'wins': 0,
#    'nominations': 2,
#    'text': 'Won 1 Oscar. Another 1 nomination.'},
#   'lastupdated': '2015-09-02 00:25:14.257000000',
#   'year': 1941,
#   'imdb': {'rating': 7.8, 'votes': 3336, 'id': 33532},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 1930, 'meter': 84},
#    'dvd': datetime.datetime(2003, 9, 30, 0, 0),
#    'critic': {'rating': 7.9, 'numReviews': 17, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 3, 19, 11, 33),
#    'rotten': 0,
#    'production': 'Criterion Collection',
#    'fresh': 17}},
#  {'_id': ObjectId('573a1393f29313caabcdc403'),
#   'plot': 'Ridiculed because of his enormous ears, a young circus elephant is assisted by a mouse to achieve his full potential.',
#   'genres': ['Animation', 'Family', 'Musical'],
#   'runtime': 64,
#   'rated': 'APPROVED',
#   'cast': ['James Baskett', 'Herman Bing', 'Billy Bletcher', 'Edward Brophy'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNWVmNWQ2OTQtNzJlNC00ZmQwLTg4ZTktZTNmM2IxZTlkOGM3L2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dumbo',
#   'fullplot': 'The stork delivers a baby elephant to Mrs. Jumbo, veteran of the circus, but the newborn is ridiculed because of his truly enormous ears and dubbed "Dumbo". After being separated from his mother, Dumbo is relegated to the circus\' clown acts; it is up to his only friend, a mouse, to assist Dumbo to achieve his full potential.',
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 10, 31, 0, 0),
#   'directors': ['Samuel Armstrong',
#    'Norman Ferguson',
#    'Wilfred Jackson',
#    'Jack Kinney',
#    'Bill Roberts',
#    'Ben Sharpsteen',
#    'John Elliotte'],
#   'writers': ['Joe Grant (screen story)',
#    'Dick Huemer (screen story)',
#    'Otto Englander (story)',
#    'Bill Peet (story)',
#    'Aurelius Battaglia (story)',
#    'Joe Rinaldi (story)',
#    'Vernon Stallings (story)',
#    'Webb Smith (story)'],
#   'awards': {'wins': 3,
#    'nominations': 1,
#    'text': 'Won 1 Oscar. Another 2 wins & 1 nomination.'},
#   'lastupdated': '2015-09-14 11:06:52.267000000',
#   'year': 1941,
#   'imdb': {'rating': 7.3, 'votes': 75991, 'id': 33563},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 431114, 'meter': 70},
#    'dvd': datetime.datetime(2001, 10, 23, 0, 0),
#    'critic': {'rating': 8.3, 'numReviews': 37, 'meter': 97},
#    'lastUpdated': datetime.datetime(2015, 9, 13, 18, 20, 57),
#    'consensus': "Dumbo packs plenty of story into its brief runtime, along with all the warm animation and wonderful music you'd expect from a Disney classic.",
#    'rotten': 1,
#    'production': 'Walt Disney Productions',
#    'fresh': 36}},
#  {'_id': ObjectId('573a1393f29313caabcdc4a2'),
#   'plot': 'Boxer Joe Pendleton dies 50 years too soon due to a heavenly mistake, and is given a new life as a millionaire playboy.',
#   'genres': ['Fantasy', 'Comedy', 'Romance'],
#   'runtime': 94,
#   'rated': 'APPROVED',
#   'cast': ['Robert Montgomery',
#    'Evelyn Keyes',
#    'Claude Rains',
#    'Rita Johnson'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNmI3NjI1YWEtOGYzNC00NGQzLTg2MjktZjE3YzNjNTM4ODkwXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Here Comes Mr. Jordan',
#   'fullplot': "Boxer Joe Pendleton, flying to his next fight, crashes...because a Heavenly Messenger, new on the job, snatched Joe's spirit prematurely from his body. Before the matter can be rectified, Joe's body is cremated; so the celestial Mr. Jordan grants him the use of the body of wealthy Bruce Farnsworth, who's just been murdered by his wife. Joe tries to remake Farnsworth's unworthy life in his own clean-cut image, but then falls in love; and what about that murderous wife?",
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 8, 21, 0, 0),
#   'directors': ['Alexander Hall'],
#   'writers': ['Sidney Buchman (screen play)',
#    'Seton I. Miller (screen play)',
#    'Harry Segall (from the play: "Heaven Can Wait")'],
#   'awards': {'wins': 4,
#    'nominations': 5,
#    'text': 'Won 2 Oscars. Another 2 wins & 5 nominations.'},
#   'lastupdated': '2015-09-05 00:27:56.940000000',
#   'year': 1941,
#   'imdb': {'rating': 7.7, 'votes': 4079, 'id': 33712},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 1037, 'meter': 83},
#    'dvd': datetime.datetime(2007, 2, 6, 0, 0),
#    'critic': {'rating': 7.4, 'numReviews': 15, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 19, 10, 19),
#    'rotten': 0,
#    'production': 'Sony Pictures Entertainment',
#    'fresh': 15}},
#  {'_id': ObjectId('573a1393f29313caabcdc4a8'),
#   'plot': 'After being released from prison, notorious thief Roy Earle is hired by his old boss to help a group of inexperienced criminals plan and carry out the robbery of a California resort.',
#   'genres': ['Adventure', 'Crime', 'Drama'],
#   'runtime': 100,
#   'rated': 'PASSED',
#   'cast': ['Ida Lupino', 'Humphrey Bogart', 'Alan Curtis', 'Arthur Kennedy'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTRhN2I1NGYtM2NlMC00MmNlLTlhYWQtNzA1YjM4ZTQ3NTJjXkEyXkFqcGdeQXVyMDQ2Njk1Ng@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'High Sierra',
#   'fullplot': "Roy 'Mad Dog' Earle is broken out of prison by an old associate who wants him to help with an upcoming robbery. When the robbery goes wrong and a man is shot and killed Earle is forced to go on the run, and with the police and an angry press hot on his tail he eventually takes refuge among the peaks of the Sierra Nevadas, where a tense siege ensues. But will the Police make him regret the attachments he formed with two women during the brief planning of the robbery.",
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 1, 25, 0, 0),
#   'directors': ['Raoul Walsh'],
#   'writers': ['John Huston (screen play)',
#    'W.R. Burnett (screen play)',
#    'W.R. Burnett (from a novel by)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-14 12:55:39.293000000',
#   'year': 1941,
#   'imdb': {'rating': 7.6, 'votes': 10801, 'id': 33717},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 5643, 'meter': 77},
#    'dvd': datetime.datetime(2003, 11, 4, 0, 0),
#    'critic': {'rating': 7.8, 'numReviews': 18, 'meter': 94},
#    'lastUpdated': datetime.datetime(2015, 9, 12, 19, 19, 44),
#    'rotten': 1,
#    'production': 'Warner Home Video',
#    'fresh': 17},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc4b3'),
#   'plot': 'At the turn of the century in a Welsh mining village, the Morgans (he stern, she gentle) raise coal-mining sons and hope their youngest will find a better life.',
#   'genres': ['Drama', 'Family'],
#   'runtime': 118,
#   'rated': 'APPROVED',
#   'cast': ['Walter Pidgeon', "Maureen O'Hara", 'Anna Lee', 'Donald Crisp'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjE1YWRmMWEtYTQ0Yy00NGEwLWFmNzAtZDkwOWNjMzkwYzJmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'How Green Was My Valley',
#   'fullplot': "Life is hard in a Welsh mining town and no less so for the Morgan family. Seen through the eyes of the family's youngest, Huw, we learn of the family's trials and tribulations. Family patriarch Gwilym and his older sons work in the mines, dangerous and unhealthy as it is. Gwilym has greater hopes for younger son how to honor his hard working parents. Huw who has his own ideas on how to honor his father. Daughter Angharad is the most beautiful girl in the valley and is very much in love with Mr. Gruffydd who isn't sure he can provide her the life she deserves. Times are hard and good men find themselves out of work and exploited by unseen mine owners.",
#   'languages': ['English', 'Welsh'],
#   'released': datetime.datetime(1942, 4, 9, 0, 0),
#   'directors': ['John Ford'],
#   'writers': ['Philip Dunne (screen play)',
#    'Richard Llewellyn (based on the novel by)'],
#   'awards': {'wins': 11,
#    'nominations': 5,
#    'text': 'Won 5 Oscars. Another 6 wins & 5 nominations.'},
#   'lastupdated': '2015-09-04 00:25:06.477000000',
#   'year': 1941,
#   'imdb': {'rating': 7.8, 'votes': 14582, 'id': 33729},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 7679, 'meter': 81},
#    'dvd': datetime.datetime(2000, 3, 7, 0, 0),
#    'critic': {'rating': 7.9, 'numReviews': 37, 'meter': 89},
#    'lastUpdated': datetime.datetime(2015, 8, 27, 18, 5, 54),
#    'consensus': "Though it perhaps strays into overly maudlin territory, this working-class drama is saved by a solid cast and director John Ford's unmistakeable style.",
#    'rotten': 4,
#    'production': 'Twentieth Century Fox Home Entertainment',
#    'fresh': 33}},
#  {'_id': ObjectId('573a1393f29313caabcdc50e'),
#   'plot': 'Documentary showing the poor state that American agriculture had fallen into during the Great Depression.',
#   'genres': ['Documentary'],
#   'runtime': 43,
#   'cast': ['Robert J. Flaherty'],
#   'num_mflix_comments': 1,
#   'title': 'The Land',
#   'fullplot': 'Documentary showing the poor state that American agriculture had fallen into during the Great Depression.',
#   'languages': ['English'],
#   'released': datetime.datetime(2001, 1, 1, 0, 0),
#   'directors': ['Robert J. Flaherty'],
#   'writers': ['Frances H. Flaherty (collaborating writer)',
#    'Robert J. Flaherty',
#    'Russell Lord (commentary)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2014-10-09 00:21:33.780000000',
#   'year': 1942,
#   'imdb': {'rating': 7.3, 'votes': 58, 'id': 33811},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 2.0, 'numReviews': 21},
#    'lastUpdated': datetime.datetime(2015, 7, 14, 18, 37, 6)}},
#  {'_id': ObjectId('573a1393f29313caabcdc514'),
#   'plot': 'The ruthless, moneyed Hubbard clan lives in, and poisons, their part of the deep South at the turn of the 20th century.',
#   'genres': ['Drama', 'Romance'],
#   'runtime': 116,
#   'rated': 'PASSED',
#   'cast': ['Bette Davis',
#    'Herbert Marshall',
#    'Teresa Wright',
#    'Richard Carlson'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMzdkYjU3ZmEtNDZkZS00ZTY5LTgzZDYtNzdiY2ZlOTg5ZDQ5XkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Little Foxes',
#   'fullplot': "The ruthless, moneyed Hubbard clan lives in, and poisons, their part of the deep South at the turn of the 20th century. Regina Giddons nèe Hubbard has her daughter under her thumb. Mrs. Giddons is estranged from her husband, who is convalescing in Baltimore and suffers from a terminal illness. But she needs him home, and will manipulate her daughter to help bring him back. She has a sneaky business deal that she's cooking up with her two elder brothers, Oscar and Ben. Oscar has a flighty, unhappy wife and a dishonest worm of a son. Will the daughter have to marry this contemptible cousin? Who will she grow up to be - her mother or her aunt? Or can she escape the fate of both?",
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 8, 29, 0, 0),
#   'directors': ['William Wyler'],
#   'writers': ['Lillian Hellman (stage play)',
#    'Lillian Hellman (screen play)',
#    'Arthur Kober (additional scenes and dialogue)',
#    'Dorothy Parker (additional scenes and dialogue)',
#    'Alan Campbell (additional scenes and dialogue)'],
#   'awards': {'wins': 10,
#    'nominations': 0,
#    'text': 'Nominated for 9 Oscars. Another 1 win.'},
#   'lastupdated': '2015-09-02 00:24:08.023000000',
#   'year': 1941,
#   'imdb': {'rating': 8.2, 'votes': 6995, 'id': 33836},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3399, 'meter': 88},
#    'dvd': datetime.datetime(2001, 9, 18, 0, 0),
#    'critic': {'rating': 8.5, 'numReviews': 14, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 1, 19, 2, 40),
#    'rotten': 0,
#    'production': 'RKO',
#    'fresh': 14},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc539'),
#   'plot': "During the depression in England, a young lady from Lancashire decides to be a rich bookmaker's mistress, just to help the rest of her family who are unemployed.",
#   'genres': ['Drama'],
#   'runtime': 94,
#   'rated': 'APPROVED',
#   'cast': ['Deborah Kerr', 'Clifford Evans', 'George Carney', 'Mary Merrall'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTYzNjcwODgyN15BMl5BanBnXkFtZTcwNjA2MDUyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love on the Dole',
#   'fullplot': "During the depression in England, a young lady from Lancashire decides to be a rich bookmaker's mistress, just to help the rest of her family who are unemployed.",
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 10, 12, 0, 0),
#   'directors': ['John Baxter'],
#   'writers': ['Walter Greenwood (novel)',
#    'Ronald Gow (play)',
#    'Walter Greenwood (adaptation)',
#    'Barbara K. Emary',
#    'Rollo Gamble'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-06-27 00:33:20.233000000',
#   'year': 1941,
#   'imdb': {'rating': 6.9, 'votes': 246, 'id': 33853},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 94, 'meter': 64},
#    'dvd': datetime.datetime(2007, 10, 30, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 13, 19, 7, 41)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc544'),
#   'plot': "A young and idealistic woman, who has adopted the Salvation Army and whose father is an armament industrialist, will save more souls directing her father's business. A comedy with social commentary.",
#   'genres': ['Comedy'],
#   'runtime': 121,
#   'rated': 'APPROVED',
#   'cast': ['Wendy Hiller', 'Rex Harrison', 'Robert Morley', 'Robert Newton'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMGQzYjBhNDQtMWFhZi00NTFmLTk5NWQtOWUwNDZlZDBlYzFmL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Major Barbara',
#   'fullplot': "A young and idealistic woman, who has adopted the Salvation Army and whose father is an armament industrialist, will save more souls directing her father's business. A comedy with social commentary.",
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 8, 2, 0, 0),
#   'directors': ['Gabriel Pascal', 'Harold French', 'David Lean'],
#   'writers': ['George Bernard Shaw (original play)',
#    'George Bernard Shaw (scenario and dialogue)',
#    'George Bernard Shaw (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-09-11 00:32:09.287000000',
#   'year': 1941,
#   'imdb': {'rating': 7.0, 'votes': 834, 'id': 33868},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 125, 'meter': 54},
#    'dvd': datetime.datetime(2010, 2, 23, 0, 0),
#    'critic': {'rating': 8.1, 'numReviews': 14, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 7, 20, 19, 10, 44),
#    'rotten': 2,
#    'production': 'Criterion Collection',
#    'fresh': 12}},
#  {'_id': ObjectId('573a1393f29313caabcdc558'),
#   'plot': "When acerbic critic Sheridan Whiteside slips on the front steps of a provincial Ohio businessman's home and breaks his hip, he and his entourage take over the house indefinitely.",
#   'genres': ['Comedy', 'Romance'],
#   'runtime': 112,
#   'rated': 'G',
#   'cast': ['Bette Davis', 'Ann Sheridan', 'Monty Woolley', 'Richard Travis'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNjUwY2Y2ZTktNTg5Ny00NWIzLWJlN2EtYjlmNzU5YTM2MjdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Man Who Came to Dinner',
#   'fullplot': 'Lecturer Sheridan Whiteside slips on the ice on his way into the home of a prominent Ohio family. The local doctor says Whiteside must remain confined having broken his leg. He begins to meddle with the lives of everyone in the household and, once his plots are underway, learns there is nothing wrong with his leg. He bribes the doctor and resumes control of the household.',
#   'languages': ['English'],
#   'released': datetime.datetime(1942, 1, 24, 0, 0),
#   'directors': ['William Keighley'],
#   'writers': ['Julius J. Epstein (screen play)',
#    'Philip G. Epstein (screen play)',
#    'George S. Kaufman (from the stage play by)',
#    'Moss Hart (from the stage play by)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-07 00:35:55.783000000',
#   'year': 1942,
#   'imdb': {'rating': 7.7, 'votes': 4657, 'id': 33874},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 1777, 'meter': 81},
#    'dvd': datetime.datetime(2006, 5, 30, 0, 0),
#    'critic': {'rating': 8.0, 'numReviews': 5, 'meter': 80},
#    'lastUpdated': datetime.datetime(2015, 8, 23, 18, 27, 34),
#    'rotten': 1,
#    'production': 'Warner Bros. Pictures',
#    'fresh': 4}},
#  {'_id': ObjectId('573a1393f29313caabcdc57c'),
#   'countries': ['Italy'],
#   'genres': ['Drama', 'War'],
#   'runtime': 77,
#   'cast': ['Augusto Basso', 'Elena'],
#   'num_mflix_comments': 1,
#   'title': 'The White Ship',
#   'lastupdated': '2015-05-22 10:56:19.617000000',
#   'languages': ['Italian'],
#   'released': datetime.datetime(1943, 3, 3, 0, 0),
#   'directors': ['Roberto Rossellini'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'year': 1941,
#   'imdb': {'rating': 6.0, 'votes': 89, 'id': 33941},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 180, 'meter': 33},
#    'lastUpdated': datetime.datetime(2015, 8, 18, 18, 59, 50)}},
#  {'_id': ObjectId('573a1393f29313caabcdc5dc'),
#   'plot': 'Professor Horatio Smith, while seeming very unassuming, rescues victims of Nazi persecution during World War II.',
#   'genres': ['Adventure', 'Comedy', 'Drama'],
#   'runtime': 120,
#   'rated': 'PASSED',
#   'cast': ['Allan Jeayes',
#    'Peter Gawthorne',
#    'Ernest Butcher',
#    'Ben Williams'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BOGU2YzM2NjYtNmRjNi00ODAxLTg2ZjMtNGQyMmIxZWU2NmI4XkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg',
#   'title': "'Pimpernel' Smith",
#   'fullplot': 'It is mid-1939 and both Germany and England are preparing for an inevitable conflict. Professor Horatio Smith, an effete academic, asks his students to come with him to the continent to engage in an archaeological dig. When his students discover that the professor is the man responsible for smuggling a number of enemies of the Nazi state out of Germany, they enthusiastically join him in his fight. But things are complicated when one of his students brings a mysterious woman into their circle, a woman who is secretly working for the Gestapo.',
#   'languages': ['English', 'German'],
#   'released': datetime.datetime(1941, 7, 28, 0, 0),
#   'directors': ['Leslie Howard'],
#   'writers': ['Anatole de Grunwald (screenplay)',
#    'A.G. Macdonell (original story)',
#    'Wolfgang Wilhelm (original story)',
#    'Anatole de Grunwald (scenario)',
#    'Roland Pertwee (scenario)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-07 00:48:49.523000000',
#   'year': 1941,
#   'imdb': {'rating': 7.4, 'votes': 794, 'id': 34027},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 291, 'meter': 75},
#    'lastUpdated': datetime.datetime(2015, 7, 6, 20, 8, 53)}},
#  {'_id': ObjectId('573a1393f29313caabcdc62b'),
#   'plot': 'Stranded in Africa, Chuck and his pal Fearless have comic versions of jungle adventures, featuring two attractive con-women.',
#   'genres': ['Adventure', 'Comedy', 'Musical'],
#   'runtime': 91,
#   'rated': 'PASSED',
#   'cast': ['Bing Crosby', 'Bob Hope', 'Dorothy Lamour', 'Una Merkel'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BOGZmOWEyMTgtZjIwZi00ZWZjLWJiODEtZTNjNzkyNTUzOWRmL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNDQzMDg4Nzk@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Road to Zanzibar',
#   'fullplot': 'Chuck and his pal Fearless flee a South African carnival when their sideshow causes a fire. After several similar escapades, they\'ve finally saved enough to return to the USA, when Chuck spends it all on a "lost" diamond mine. But that\'s only the beginning; before long, a pair of attractive con-women have tricked our heroes into financing a comic safari, featuring numerous burlesque jungle adventures...',
#   'languages': ['English', 'French'],
#   'released': datetime.datetime(1941, 4, 11, 0, 0),
#   'directors': ['Victor Schertzinger'],
#   'writers': ['Frank Butler (screenplay)',
#    'Don Hartman (screenplay)',
#    'Don Hartman (based on a story by)',
#    'Sy Bartlett (based on a story by)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-17 04:43:21.363000000',
#   'year': 1941,
#   'imdb': {'rating': 7.2, 'votes': 2225, 'id': 34116},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 2599, 'meter': 64},
#    'dvd': datetime.datetime(2002, 3, 5, 0, 0),
#    'critic': {'rating': 6.6, 'numReviews': 7, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 8, 6, 19, 2, 44),
#    'rotten': 1,
#    'production': 'Universal Pictures',
#    'fresh': 6},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc664'),
#   'plot': 'Humphrey van Weyden, a writer, and fugitives Ruth Webster and George Leach have been given refuge aboard the sealer "Ghost," captained by the cruel Wolf Larsen. The crew mutinies against ...',
#   'genres': ['Drama', 'Adventure'],
#   'runtime': 100,
#   'rated': 'APPROVED',
#   'cast': ['Edward G. Robinson',
#    'Ida Lupino',
#    'John Garfield',
#    'Alexander Knox'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDE3OGNmMTAtZWQyMi00ZDM0LWEwYTEtNmQ3MGZlNDQzYjIzXkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Sea Wolf',
#   'fullplot': 'Humphrey van Weyden, a writer, and fugitives Ruth Webster and George Leach have been given refuge aboard the sealer "Ghost," captained by the cruel Wolf Larsen. The crew mutinies against Larsen\'s many crimes, and though van Weyden, Ruth, and George try to escape Larsen\'s clutches, they find themselves drawn inexorably back to him as the "Ghost" sails toward disaster.',
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 3, 21, 0, 0),
#   'directors': ['Michael Curtiz'],
#   'writers': ['Jack London (novel)', 'Robert Rossen (screen play)'],
#   'awards': {'wins': 0,
#    'nominations': 2,
#    'text': 'Nominated for 1 Oscar. Another 1 nomination.'},
#   'lastupdated': '2015-08-05 00:51:47.617000000',
#   'year': 1941,
#   'imdb': {'rating': 7.6, 'votes': 2115, 'id': 34162},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 221, 'meter': 83},
#    'dvd': datetime.datetime(2005, 3, 8, 0, 0),
#    'production': 'Warner Bros. Pictures',
#    'lastUpdated': datetime.datetime(2015, 9, 16, 17, 51, 41)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc672'),
#   'plot': 'A hillbilly sharpshooter drafted in WW1 despite his claim to be a pacifist, who ends up becoming a war hero.',
#   'genres': ['Biography', 'Drama', 'History'],
#   'runtime': 134,
#   'rated': 'APPROVED',
#   'cast': ['Gary Cooper', 'Walter Brennan', 'Joan Leslie', 'George Tobias'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYmEzN2M4YjgtZmQ2MC00ZGI3LWEwNWEtNDRjNGE0N2FiMzQzXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Sergeant York',
#   'fullplot': 'A hillbilly sharpshooter becomes one of the most celebrated American heroes of WWI when he single-handedly attacks and captures a German position using the same strategy as in turkey shoot.',
#   'languages': ['English', 'French', 'German'],
#   'released': datetime.datetime(1941, 9, 27, 0, 0),
#   'directors': ['Howard Hawks'],
#   'writers': ['Abem Finkel (original screen play)',
#    'Harry Chandlee (original screen play)',
#    'Howard Koch (original screen play)',
#    'John Huston (original screen play)',
#    'Alvin C. York (based upon: the diary of)',
#    'Tom Skeyhill (diary editor)'],
#   'awards': {'wins': 5,
#    'nominations': 9,
#    'text': 'Won 2 Oscars. Another 3 wins & 9 nominations.'},
#   'lastupdated': '2015-08-25 00:01:49.650000000',
#   'year': 1941,
#   'imdb': {'rating': 7.8, 'votes': 11577, 'id': 34167},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 5540, 'meter': 87},
#    'dvd': datetime.datetime(2006, 11, 7, 0, 0),
#    'critic': {'rating': 6.9, 'numReviews': 19, 'meter': 84},
#    'lastUpdated': datetime.datetime(2015, 8, 25, 18, 22, 25),
#    'rotten': 3,
#    'production': 'Warner Bros. Pictures',
#    'fresh': 16}},
#  {'_id': ObjectId('573a1393f29313caabcdc6af'),
#   'countries': ['Soviet Union'],
#   'genres': ['Musical', 'Romance'],
#   'runtime': 87,
#   'cast': ['Marina Ladynina',
#    'Vladimir Zeldin',
#    'Nikolay Kryuchkov',
#    'N. Kitayev'],
#   'num_mflix_comments': 1,
#   'title': 'They Met in Moscow',
#   'lastupdated': '2015-02-25 09:48:42.880000000',
#   'languages': ['Russian'],
#   'released': datetime.datetime(1944, 6, 6, 0, 0),
#   'directors': ['Ivan Pyryev'],
#   'writers': ['Viktor Gusev'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'year': 1941,
#   'imdb': {'rating': 7.1, 'votes': 81, 'id': 34249},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 428, 'meter': 67},
#    'lastUpdated': datetime.datetime(2015, 7, 27, 18, 2, 8)}},
#  {'_id': ObjectId('573a1393f29313caabcdc6c6'),
#   'plot': "Sir William Hamilton, a widower of mature years, is British ambassador to the Court of Naples. Emma who comes for a visit with her mother wouldn't cut the grade with London society but she ...",
#   'genres': ['Drama', 'History', 'Romance'],
#   'runtime': 128,
#   'rated': 'APPROVED',
#   'cast': ['Vivien Leigh', 'Laurence Olivier', 'Alan Mowbray', 'Sara Allgood'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZGVlYTFjNjEtYmM5OC00YjIxLThlNjAtZTIxOWU1NGI0YTViXkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'That Hamilton Woman',
#   'fullplot': 'Sir William Hamilton, a widower of mature years, is British ambassador to the Court of Naples. Emma who comes for a visit with her mother wouldn\'t cut the grade with London society but she gets along well with the Queen of Naples. Emma likes being Lady Hamilton and life goes smoothly until Lord Nelson pays a visit. Sir William decides at first to let his young wife have her fling and pretends not to know what is going on. But the real life lovers, whose first screen romance was in "Fire Over England" (1937) have an even more burning passion for each other in this film.',
#   'languages': ['English', 'French', 'Italian'],
#   'released': datetime.datetime(1941, 4, 30, 0, 0),
#   'directors': ['Alexander Korda'],
#   'writers': ['Walter Reisch (original screenplay)',
#    'R.C. Sherriff (original screenplay)'],
#   'awards': {'wins': 0,
#    'nominations': 4,
#    'text': 'Won 1 Oscar. Another 3 nominations.'},
#   'lastupdated': '2015-09-05 00:28:15.847000000',
#   'year': 1941,
#   'imdb': {'rating': 7.4, 'votes': 2626, 'id': 34272},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 1610, 'meter': 85},
#    'dvd': datetime.datetime(2009, 9, 8, 0, 0),
#    'critic': {'rating': 7.3, 'numReviews': 9, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 19, 15, 17),
#    'rotten': 0,
#    'production': 'HBO Video',
#    'fresh': 9}},
#  {'_id': ObjectId('573a1393f29313caabcdc6e9'),
#   'plot': 'Working girl Janie is proposed to by a conservative car salesman, a bohemian auto mechanic, and a millionaire playboy and must make a choice.',
#   'genres': ['Comedy', 'Fantasy', 'Romance'],
#   'runtime': 87,
#   'rated': 'APPROVED',
#   'cast': ['Ginger Rogers',
#    'George Murphy',
#    'Alan Marshal',
#    'Burgess Meredith'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTBkZjhmYjYtYmZjOS00NzAwLWFlMDUtZDRlNmYzYzU1YzIzXkEyXkFqcGdeQXVyNjc0MzMzNjA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Tom Dick and Harry',
#   'fullplot': "Working girl/telephone operator Janie is engaged to conservative, dull, but very reliable car salesman Tom, who offers her a safe, stable marriage. Then she meets unconventional slacker Harry, a philosophical car mechanic without much ambition although she does hear bells when they kiss. Through Harry, the fickle Janie meets Dick, a handsome and charming millionaire playboy, who embodies her greatest romantic fantasies, and after a champagne-filled overnight flight to Chicago, she thinks she's met her dream man, but has she?",
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 6, 13, 0, 0),
#   'directors': ['Garson Kanin'],
#   'writers': ['Paul Jarrico (story)', 'Paul Jarrico (screenplay)'],
#   'awards': {'wins': 2,
#    'nominations': 0,
#    'text': 'Nominated for 1 Oscar. Another 1 win.'},
#   'lastupdated': '2015-08-06 00:54:45.193000000',
#   'year': 1941,
#   'imdb': {'rating': 6.7, 'votes': 707, 'id': 34299},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 239, 'meter': 41},
#    'dvd': datetime.datetime(2009, 4, 20, 0, 0),
#    'production': 'Warner Home Video',
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 36, 12)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc6f0'),
#   'plot': 'When the patriarch of the Toda family suddenly dies, his widow discovers that he has left her with nothing but debt and married children who are unwilling to support her--except for her most thoughtful son, just returned from China.',
#   'genres': ['Drama'],
#   'runtime': 105,
#   'cast': ['Mieko Takamine', 'Shin Saburi', 'Hideo Fujino', 'Ayako Katsuragi'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNTgyZTI4MmYtYTdjZi00NjQ2LWE2ZDItMzNkM2Y4NjA0YzZmXkEyXkFqcGdeQXVyNjUwMTQ4NjE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Brothers and Sisters of the Toda Family',
#   'fullplot': 'When the patriarch of the Toda family suddenly dies, his widow discovers that he has left her with nothing but debt and married children who are unwilling to support her--except for her most thoughtful son, just returned from China.',
#   'languages': ['Japanese'],
#   'released': datetime.datetime(1982, 5, 11, 0, 0),
#   'directors': ['Yasujirè Ozu'],
#   'writers': ['Tadao Ikeda', 'Yasujirè Ozu'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-02 00:27:55.680000000',
#   'year': 1941,
#   'imdb': {'rating': 7.6, 'votes': 648, 'id': 34298},
#   'countries': ['Japan'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 239, 'meter': 41},
#    'dvd': datetime.datetime(2009, 4, 20, 0, 0),
#    'production': 'Warner Home Video',
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 36, 12)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc706'),
#   'plot': 'While at a ski lodge, Larry Blake sees instructor Karin Borg and decides to sign up for private lessons. The next thing he knows, she is Mrs. Blake. When he announces that he is going back ...',
#   'genres': ['Comedy', 'Romance'],
#   'runtime': 90,
#   'rated': 'PASSED',
#   'cast': ['Greta Garbo',
#    'Melvyn Douglas',
#    'Constance Bennett',
#    'Roland Young'],
#   'num_mflix_comments': 1,
#   'title': 'Two-Faced Woman',
#   'fullplot': "While at a ski lodge, Larry Blake sees instructor Karin Borg and decides to sign up for private lessons. The next thing he knows, she is Mrs. Blake. When he announces that he is going back to work on his magazine in New York the next day, Karin refuses to go with him. She later comes to New York, buys expensive clothes, and goes to meet him when she sees he is with old flame Griselda. Caught by Blake's business partner, O.O. Miller, before she can leave, she explains that she is really Karin's twin sister Katherine. Hard to believe, but that is what she tries to make everyone, including Larry, believe. Larry, however, has serious doubts, but plays the game to the hilt as the worldly Katherine tries to take him away from both Griselda and Karin.",
#   'languages': ['English'],
#   'released': datetime.datetime(1942, 3, 2, 0, 0),
#   'directors': ['George Cukor'],
#   'writers': ['S.N. Behrman (original screenplay)',
#    'Salka Viertel (original screenplay)',
#    'George Oppenheimer (original screenplay)',
#    'Ludwig Fulda (suggested by a play by)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-13 00:25:44.317000000',
#   'year': 1941,
#   'imdb': {'rating': 6.4, 'votes': 1020, 'id': 34328},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 322, 'meter': 25},
#    'critic': {'rating': 4.2, 'numReviews': 8, 'meter': 25},
#    'lastUpdated': datetime.datetime(2015, 8, 9, 18, 42, 37),
#    'rotten': 6,
#    'production': 'MGM',
#    'fresh': 2}},
#  {'_id': ObjectId('573a1393f29313caabcdc742'),
#   'plot': 'A practical man returns to his homeland, is attacked by a creature of folklore, and infected with a horrific disease his disciplined mind tells him can not possibly exist.',
#   'genres': ['Drama', 'Horror'],
#   'runtime': 70,
#   'rated': 'APPROVED',
#   'cast': ['Lon Chaney Jr.',
#    'Claude Rains',
#    'Warren William',
#    'Ralph Bellamy'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BODRmMDBjMTYtZmJiZi00Mzk3LWFhZDAtMDExNDFhMWQzNzEyXkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Wolf Man',
#   'fullplot': "Upon the death of his brother, Larry Talbot returns from America to his ancestral home in Wales. He visits a gypsy camp with village girl Jenny Williams, who is attacked by Bela, a gypsy who has turned into a werewolf. Larry kills the werewolf but is bitten during the fight. Bela's mother tells him that this will cause him to become a werewolf at each full moon. Larry confesses his plight to his unbelieving father, Sir John, who then joins the villagers in a hunt for the wolf. Transformed by the full moon, Larry heads for the forest and a fateful meeting with both Sir John and Gwen Conliffe.",
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 12, 12, 0, 0),
#   'directors': ['George Waggner'],
#   'writers': ['Curt Siodmak (original screenplay)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-01 00:16:01.100000000',
#   'year': 1941,
#   'imdb': {'rating': 7.4, 'votes': 14875, 'id': 34398},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 10053, 'meter': 80},
#    'dvd': datetime.datetime(2001, 8, 28, 0, 0),
#    'critic': {'rating': 7.9, 'numReviews': 35, 'meter': 94},
#    'lastUpdated': datetime.datetime(2015, 9, 12, 18, 10, 25),
#    'consensus': 'A handsomely told tale with an affecting performance from Lon Chaney, Jr., The Wolf Man remains one of the classics of the Universal horror stable.',
#    'rotten': 2,
#    'production': 'Universal Pictures',
#    'fresh': 33}},
#  {'_id': ObjectId('573a1393f29313caabcdc77e'),
#   'plot': 'Rick Leland makes no secret of the fact he has no loyalty to his home country after he is court-marshaled out of the army and boards a Japanese ship for the Orient in late 1941. But has ...',
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'runtime': 97,
#   'rated': 'APPROVED',
#   'cast': ['Humphrey Bogart',
#    'Mary Astor',
#    'Sydney Greenstreet',
#    'Charles Halton'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYWYwZDQ5ZmItOGIyYy00NTc0LTg2N2YtZDE5YmE2NzY3YzIxL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Across the Pacific',
#   'fullplot': 'Rick Leland makes no secret of the fact he has no loyalty to his home country after he is court-marshaled out of the army and boards a Japanese ship for the Orient in late 1941. But has Leland really been booted out, or is there some other motive for his getting close to fellow passenger Doctor Lorenz? Any motive for getting close to attractive traveller Alberta Marlow would however seem pretty obvious.',
#   'languages': ['English', 'Japanese'],
#   'released': datetime.datetime(1942, 9, 5, 0, 0),
#   'directors': ['John Huston', 'Vincent Sherman'],
#   'writers': ['Richard Macaulay (screenplay)',
#    'Robert Carson (serial "Aloha Means Goodbye")'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-23 00:05:01.140000000',
#   'year': 1942,
#   'imdb': {'rating': 6.9, 'votes': 2892, 'id': 34428},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 1302, 'meter': 59},
#    'dvd': datetime.datetime(2006, 10, 24, 0, 0),
#    'production': 'Warner Home Video',
#    'lastUpdated': datetime.datetime(2015, 8, 22, 19, 7, 50)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdc7aa'),
#   'plot': 'The story of a young deer growing up in the forest after his mother is shot by hunters.',
#   'genres': ['Animation', 'Family'],
#   'runtime': 70,
#   'rated': 'APPROVED',
#   'cast': ['Hardie Albright',
#    'Stan Alexander',
#    'Bobette Audrey',
#    'Peter Behn'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY1NzM4NDg5MV5BMl5BanBnXkFtZTgwMjI1MTkzMjE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Bambi',
#   'lastupdated': '2015-09-10 17:25:51.623000000',
#   'languages': ['English'],
#   'released': datetime.datetime(1942, 8, 14, 0, 0),
#   'directors': ['James Algar',
#    'Samuel Armstrong',
#    'David Hand',
#    'Graham Heid',
#    'Bill Roberts',
#    'Paul Satterfield',
#    'Norman Wright'],
#   'writers': ['Felix Salten (from the story by)',
#    'Perce Pearce (story)',
#    'Larry Morey (story)',
#    'Vernon Stallings (story)',
#    'Mel Shaw (story)',
#    'Carl Fallberg (story)',
#    'Chuck Couch (story)',
#    'Ralph Wright (story)'],
#   'awards': {'wins': 6,
#    'nominations': 1,
#    'text': 'Nominated for 3 Oscars. Another 3 wins & 1 nomination.'},
#   'year': 1942,
#   'imdb': {'rating': 7.4, 'votes': 83357, 'id': 34492},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 598412, 'meter': 72},
#    'dvd': datetime.datetime(2005, 3, 1, 0, 0),
#    'critic': {'rating': 8.3, 'numReviews': 46, 'meter': 91},
#    'lastUpdated': datetime.datetime(2015, 9, 14, 21, 0, 13),
#    'consensus': 'Elegantly animated and deeply touching, Bambi is an enduring, endearing, and moving Disney classic.',
#    'rotten': 4,
#    'production': 'RKO Radio Pictures',
#    'fresh': 42}},
#  {'_id': ObjectId('573a1393f29313caabcdc7c9'),
#   'plot': "An ex-pirate contends with rowdy buccaneers and a love-hate relationship with an aristocratic woman who's tougher than she seems.",
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'runtime': 87,
#   'rated': 'APPROVED',
#   'cast': ['Tyrone Power',
#    "Maureen O'Hara",
#    'Laird Cregar',
#    'Thomas Mitchell'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1ODM0NTM2NF5BMl5BanBnXkFtZTgwMTI0MjczMjE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Black Swan',
#   'fullplot': "When notorious pirate Henry Morgan is made governor of Jamaica, he enlists the help of some of his former partners in ridding the Carribean of Buccaneers. When one of them apparently abducts the previous governor's pretty daughter and joins up with the rebels, things are set for a fight.",
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1942, 12, 4, 0, 0),
#   'directors': ['Henry King'],
#   'writers': ['Ben Hecht (screenplay)',
#    'Seton I. Miller (screenplay)',
#    'Seton I. Miller (adaptation)',
#    'Rafael Sabatini (novel)'],
#   'awards': {'wins': 0,
#    'nominations': 3,
#    'text': 'Won 1 Oscar. Another 2 nominations.'},
#   'lastupdated': '2015-08-23 01:11:57.787000000',
#   'year': 1942,
#   'imdb': {'rating': 7.0, 'votes': 2779, 'id': 34522},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 1324, 'meter': 73},
#    'dvd': datetime.datetime(2006, 7, 11, 0, 0),
# ...
#    'Eric Gurney (story)',
#    'Sylvia Moberly-Holland (story)',
#    'T. Hee (story)',
#    'Erdman Penner (story)',
#    'Dick Kelsey (story)',
#    'James Bodrero (story)',
#    'Roy Williams (story)',
#    'Cap Palmer (story)',
#    'Jesse Marsh (story)',
#    'Erwin Graham (story)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-08-30 03:58:01.037000000',
#   'year': 1946,
#   'imdb': {'rating': 6.5, 'votes': 2033, 'id': 38718},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 2273, 'meter': 43},
#    'dvd': datetime.datetime(2000, 6, 6, 0, 0),
#    'critic': {'rating': 6.3, 'numReviews': 9, 'meter': 67},
#    'lastUpdated': datetime.datetime(2015, 8, 31, 18, 53, 52),
#    'consensus': "This collection of musical-themed shorts doesn't reach the artistic heights of Fantasia, but it's well animated and mostly good fun.",
#    'rotten': 3,
#    'fresh': 6},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139df29313caabcf8f76'),
#   'plot': 'The films takes an expressionist look at the gulf between the rich and poor in the society. The film centers on a wealthy and capacious landlord, Sarkar (Rafi Peer) who lives in a palatial ...',
#   'runtime': 122,
#   'cast': ['Rafiq Anwar', 'Uma Anand', 'Kamini Kaushal', 'Rafi Peer'],
#   'title': 'Neecha Nagar',
#   'fullplot': "The films takes an expressionist look at the gulf between the rich and poor in the society. The film centers on a wealthy and capacious landlord, Sarkar (Rafi Peer) who lives in a palatial estate high up on a mountain while the poor toil and starve in the valley below. The villagers of 'Neecha Nagar' harbor hate for Sarkar and their hatred is fueled even more by the fact that Sarkar plans to direct all the sewage into the village in order to make way for his housing project. The villagers protest this move with their head, Balraj (Rafiq Anwar) leading a movement against Sarkar's plan. Sarkar's daughter Maya (Uma Anand) joins the movement against her father and falls in love with Balraj. With the sewage flowing through the village, epidemic starts to spread and the lives of the villagers comes under threat. Can poor people of 'Neecha Nagar' survive the greed and wickedness of the rich? Can Sarkar and his malicious ways be put to an end?",
#   'languages': ['Hindi'],
#   'released': datetime.datetime(1946, 9, 1, 0, 0),
#   'directors': ['Chetan Anand'],
#   'writers': ['Hayatulla Ansari (story)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-05-30 00:35:30.953000000',
#   'year': 1946,
#   'imdb': {'rating': 7.7, 'votes': 66, 'id': 154942},
#   'countries': ['India'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 63, 'meter': 71},
#    'dvd': datetime.datetime(2006, 10, 3, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 7, 20, 0, 31)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139df29313caabcfa6cd'),
#   'plot': "Cantinflas is a private, who doesn't know anything about discipline or following rules. He only wants to think about his girlfriend, the maid in an opulent hacienda. The owner has an ugly ...",
#   'genres': ['Comedy'],
#   'runtime': 113,
#   'cast': ['Cantinflas',
#    'èngel Garasa',
#    "Daniel 'Chino' Herrera",
#    'Andrès Soler'],
#   'num_mflix_comments': 0,
#   'title': 'èA volar joven!',
#   'fullplot': "Cantinflas is a private, who doesn't know anything about discipline or following rules. He only wants to think about his girlfriend, the maid in an opulent hacienda. The owner has an ugly and shy daughter, who is in love with Cantinflas. The problems arrive when the family arrange a wedding between the ugly girl and Cantinflas, who in order to avoid the commitment causes himself an arrest. During the punishment, Cantinflas will learn to fly with a silly and not to much trained instructor.",
#   'languages': ['Spanish'],
#   'released': datetime.datetime(1947, 12, 25, 0, 0),
#   'directors': ['Miguel M. Delgado'],
#   'writers': ['Paul Colline (story)',
#    'Miguel M. Delgado (screenplay)',
#    'Jaime Salvador (adaptation)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-31 00:20:25.403000000',
#   'year': 1947,
#   'imdb': {'rating': 7.2, 'votes': 183, 'id': 161215},
#   'countries': ['Mexico'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.stealthismovie.net',
#    'viewer': {'rating': 3.6, 'numReviews': 2912, 'meter': 72},
#    'dvd': datetime.datetime(2001, 4, 24, 0, 0),
#    'critic': {'rating': 5.4, 'numReviews': 43, 'meter': 51},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 18, 49, 15),
#    'consensus': "D'Onofrio's performance fails to do justice to Hoffman, and the depiction of the 60s also rings false.",
#    'rotten': 21,
#    'production': 'LionsGate Entertainment',
#    'fresh': 22}},
#  {'_id': ObjectId('573a139ef29313caabcfd5ef'),
#   'plot': 'The World War II US Government account of the European theatre of the war from after the English and French entry to the fall of France.',
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 57,
#   'title': 'Divide and Conquer',
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTczNzE1MTQ4MF5BMl5BanBnXkFtZTgwNjM1MzgwMzE@._V1._CR47,47,266,392_SY264_CR0,0,178,264_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': 'In this episode of the Why We Fight propaganda series, the events from the English and French declarations of war against Nazi Germany to the conquest of France by the Nazi. In detail, we learn of how a combination of innovative Nazi military tactics and the work of traitors allowed the conquest of much of Central Europe.',
#   'languages': ['English'],
#   'cast': ['General Bergeret',
#    'Karl Brandt',
#    'Winston Churchill',
#    'Warren J. Clear'],
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-08-27 00:01:32.400000000',
#   'year': 1943,
#   'imdb': {'rating': 7.4, 'votes': 434, 'id': 173769},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 204, 'meter': 64},
#    'dvd': datetime.datetime(1998, 10, 13, 0, 0),
#    'production': 'Roy Frumkes Productions',
#    'lastUpdated': datetime.datetime(2015, 9, 3, 19, 49, 15)}},
#  {'_id': ObjectId('573a139ff29313caabcff7d1'),
#   'plot': "The official World War II US government account of Great Britain's stand against the Nazi war machine after the Dunkirk evacuation.",
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 54,
#   'cast': ['Douglas Bader',
#    'Arno Breker',
#    'Winston Churchill',
#    'Hermann Gèring'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTgzMzQwMTYwOV5BMl5BanBnXkFtZTgwOTk2NDgwMzE@._V1._CR41,48,282,391_SY132_CR3,0,89,132_AL_.jpg',
#   'title': 'The Battle of Britain',
#   'fullplot': 'In this installment of the "Why We Fight" propaganda film series, we have the account of Great Britain\'s last stand against the forces of Nazi Germany. This mainly focuses on the desperate, but successful, battle to maintain their vital air superiority over the British Isles and the morale of the people to prevent invasion.',
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 11, 26, 0, 0),
#   'directors': ['Frank Capra', 'Anthony Veiller'],
#   'writers': ['Julius J. Epstein', 'Philip G. Epstein'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-08-13 00:25:33.130000000',
#   'year': 1943,
#   'imdb': {'rating': 7.5, 'votes': 497, 'id': 182766},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 80, 'meter': 67},
#    'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#    'production': 'US Army',
#    'lastUpdated': datetime.datetime(2015, 8, 12, 19, 2, 43)}},
#  {'_id': ObjectId('573a139ff29313caabcff8ae'),
#   'plot': 'The World War II US Government account of the European theatre of the war from after the English and French entry to the fall of France.',
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 57,
#   'title': 'Divide and Conquer',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTczNzE1MTQ4MF5BMl5BanBnXkFtZTgwNjM1MzgwMzE@._V1._CR47,47,266,392_SY264_CR0,0,178,264_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': 'In this episode of the Why We Fight propaganda series, the events from the English and French declarations of war against Nazi Germany to the conquest of France by the Nazi. In detail, we learn of how a combination of innovative Nazi military tactics and the work of traitors allowed the conquest of much of Central Europe.',
#   'languages': ['English'],
#   'cast': ['General Bergeret',
#    'Karl Brandt',
#    'Winston Churchill',
#    'Warren J. Clear'],
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-05-11 00:01:41.183000000',
#   'year': 1943,
#   'imdb': {'rating': 7.4, 'votes': 421, 'id': 182989},
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.thedogwalker.com',
#    'viewer': {'rating': 3.0, 'numReviews': 34},
#    'dvd': datetime.datetime(2003, 11, 25, 0, 0),
#    'critic': {'rating': 4.8, 'numReviews': 10, 'meter': 50},
#    'lastUpdated': datetime.datetime(2015, 6, 15, 18, 33, 46),
#    'rotten': 5,
#    'production': 'Outrider Pictures',
#    'fresh': 5},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139ff29313caabcffc7d'),
#   'plot': 'Part VII of the "Why We Fight" series of wartime documentaries. This entry attempts to describe the factors leading up to America\'s entry into the Second World War.',
#   'genres': ['Documentary', 'War'],
#   'runtime': 70,
#   'cast': ['Dean Acheson', 'General Bergeret', 'A.A. Berle', 'Arno Breker'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTc4NjI1NzM3OV5BMl5BanBnXkFtZTcwNzg4NjcyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'War Comes to America',
#   'fullplot': 'In this final installment of the "Why We Fight" propaganda series, the subject focuses on the United States of America. We learn of its good qualities and the things worth fighting for. With that established, we learn of the history of the United States\' population shifting opinion towards siding with the Allies against the Axis until the attack on Pearl Harbour which brought America into full scale involvement in the war.',
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 6, 14, 0, 0),
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'writers': ['Julius J. Epstein',
#    'Philip G. Epstein',
#    'Adolf Hitler (book)',
#    'Anatole Litvak',
#    'Anthony Veiller'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-25 00:02:31.697000000',
#   'year': 1945,
#   'imdb': {'rating': 7.1, 'votes': 410, 'id': 183997},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 30},
#    'production': 'Indican Pictures',
#    'lastUpdated': datetime.datetime(2015, 5, 10, 18, 27, 19)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139ff29313caabcffd74'),
#   'plot': 'The Official World War II US Government account of Chinese defense against Japanese aggression.',
#   'genres': ['Documentary', 'History', 'War'],
#   'runtime': 65,
#   'cast': ['Claire Chennault', 'Kai-Shek Chiang', 'Madame Chiang', 'Teh Chu'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA4MjIyMzQyOV5BMl5BanBnXkFtZTcwMDI3MDc0NQ@@._V1._CR35,33,281,418_SX178_AL_.jpg',
#   'title': 'The Battle of China',
#   'fullplot': 'In this installment of the "Why We Fight" propaganda series, we learn about the country of China and its people. With a brief history of the country, we also learn of why the Japanese wanted to conquer it and felt confident about succeeding. Finally, the history of the war in that theatre is illustrated and shows the stiff determination of the Chinese who use all their resources to oppose Japanese aggression to the end.',
#   'languages': ['English'],
#   'released': datetime.datetime(2005, 4, 6, 0, 0),
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'writers': ['Julius J. Epstein', 'Philip G. Epstein'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-22 00:59:59.873000000',
#   'year': 1944,
#   'imdb': {'rating': 7.3, 'votes': 407, 'id': 184254},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 1},
#    'lastUpdated': datetime.datetime(2015, 8, 8, 18, 57, 46)}},
#  {'_id': ObjectId('573a139ff29313caabcfff82'),
#   'plot': 'The official World War II US government account of Nazi international aggression leading up to the British and French declarations of war.',
#   'genres': ['Documentary', 'Short', 'War'],
#   'runtime': 41,
#   'title': 'The Nazis Strike',
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTM0MjQ1MDk0MV5BMl5BanBnXkFtZTcwNzkwMDYxMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': "In this installment of the Why We Fight propaganda film series, we see the events of Nazi Germany's diplomatic and military acts of international aggression. One by one, we learn of the Nazi's consistently underhanded and relenting violation of every promise of peace and exploitation of their foes's attempts of appeasement until the invasion of Poland September of 1939 which led to Britain and France finally taking an armed stand against Hitler.",
#   'languages': ['English'],
#   'cast': ['Eduard Benes',
#    'Neville Chamberlain',
#    'Clementine Churchill',
#    'Winston Churchill'],
#   'directors': ['Frank Capra', 'Anatole Litvak'],
#   'writers': ['Julius J. Epstein', 'Philip G. Epstein', 'Adolf Hitler (book)'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-08-23 00:19:55.123000000',
#   'year': 1943,
#   'imdb': {'rating': 7.3, 'votes': 523, 'id': 184773},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 7},
#    'dvd': datetime.datetime(1999, 12, 7, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 7, 16, 18, 45, 2)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13b2f29313caabd38c8d'),
#   'plot': 'Emi Ota and her friend Okiku stay briefly at a mountain inn and then return to Tokyo. Later, Nanmura, a soldier on leave, steps on an ornamental hairpin in the public bath at the inn. Emi ...',
#   'genres': ['Drama'],
#   'runtime': 70,
#   'cast': ["Shin'ichi Himori",
#    'Kanji Kawahara',
#    'Hiroko Kawasaki',
#    'Koji Matsumoto'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZTAyYjc3ZGEtNTkzZi00Y2I1LWE3ZDEtYWI1MmYyOTFmY2UwXkEyXkFqcGdeQXVyMzY2MDk0MTk@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Ornamental Hairpin',
#   'fullplot': 'Emi Ota and her friend Okiku stay briefly at a mountain inn and then return to Tokyo. Later, Nanmura, a soldier on leave, steps on an ornamental hairpin in the public bath at the inn. Emi writes to the inn saying she has lost a hairpin and, when she discovers that it injured Nanmura, returns to apologize. The longer term visitors at the inn meet together to discuss the hairpin incident. These include a grumpy Professor, a young couple Mr and Mrs Hiroyasu, and an old man staying with his two grandsons. They hope to see a romance blossom between Nanmura and Emi, after Nanmura declares that there is something almost poetic in finding a hairpin in the bath.',
#   'languages': ['Japanese'],
#   'released': datetime.datetime(1941, 8, 26, 0, 0),
#   'directors': ['Hiroshi Shimizu'],
#   'writers': ['Masuji Ibuse (story)', 'Yoshitomo Nagase'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-07-12 00:34:55.437000000',
#   'year': 1941,
#   'imdb': {'rating': 7.3, 'votes': 335, 'id': 427424},
#   'countries': ['Japan'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 80, 'meter': 84},
#    'dvd': datetime.datetime(2009, 3, 17, 0, 0),
#    'critic': {'numReviews': 1},
#    'lastUpdated': datetime.datetime(2015, 1, 7, 2, 25),
#    'rotten': 0,
#    'production': 'Criterion Collection',
#    'fresh': 1}}]

# %% [markdown]
# #### Задача 1.5 — **1 балл**

# %% [markdown]
# Модифицируйте запрос из задачи 1.4 таким образом, чтобы осуществить _проекцию_: результатом выборки должен стать список словарей, каждый из которых содержит только два поля: `title` и `year`.
#
# Для справки о проекции см. документацию по методу `find()` в pymongo:
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.find

# %%
# Ваш код здесь

{x['title']: x['year'] for x in list(db['movies'].find({'year': {'$gt': 1940, '$lt': 1949}}))}
# Out:
# {'Blood and Sand': 1941,
#  'The Blood of Jesus': 1941,
#  'Blossoms in the Dust': 1941,
#  'Citizen Kane': 1941,
#  'The Devil and Daniel Webster': 1941,
#  'Dumbo': 1941,
#  'Here Comes Mr. Jordan': 1941,
#  'High Sierra': 1941,
#  'How Green Was My Valley': 1941,
#  'The Land': 1942,
#  'The Little Foxes': 1941,
#  'Love on the Dole': 1941,
#  'Major Barbara': 1941,
#  'The Man Who Came to Dinner': 1942,
#  'The White Ship': 1941,
#  "'Pimpernel' Smith": 1941,
#  'Road to Zanzibar': 1941,
#  'The Sea Wolf': 1941,
#  'Sergeant York': 1941,
#  'They Met in Moscow': 1941,
#  'That Hamilton Woman': 1941,
#  'Tom Dick and Harry': 1941,
#  'The Brothers and Sisters of the Toda Family': 1941,
#  'Two-Faced Woman': 1941,
#  'The Wolf Man': 1941,
#  'Across the Pacific': 1942,
#  'Bambi': 1942,
#  'The Black Swan': 1942,
#  'Casablanca': 1942,
#  'Cat People': 1942,
#  'People on the Alps': 1942,
#  'Der groèe Kènig': 1942,
#  'The Hard Way': 1943,
#  'Holiday Inn': 1942,
#  'Jungle Book': 1942,
#  'Journey for Margaret': 1942,
#  'The Magnificent Ambersons': 1942,
#  'The Male Animal': 1942,
#  'The Major and the Minor': 1942,
#  'The Moon and Sixpence': 1942,
#  'Mrs. Miniver': 1942,
#  'My Gal Sal': 1942,
#  'Ossessione': 1943,
#  'One of Our Aircraft Is Missing': 1942,
#  'The Pied Piper': 1942,
#  'Prelude to War': 1942,
#  'The Pride of the Yankees': 1942,
#  'Random Harvest': 1942,
#  'Saboteur': 1942,
#  'This Above All': 1942,
#  'To Be or Not to Be': 1942,
#  'Wake Island': 1942,
#  'Woman of the Year': 1942,
#  'Yankee Doodle Dandy': 1942,
#  'Air Force': 1943,
#  'Bataan': 1943,
#  'Cabin in the Sky': 1943,
#  'Desert Victory': 1943,
#  "The Gang's All Here": 1943,
#  'The Ghost Ship': 1943,
#  'Hangmen Also Die!': 1943,
#  'Hello Frisco, Hello': 1943,
#  'I Walked with a Zombie': 1943,
#  'Holy Matrimony': 1943,
#  'Lassie Come Home': 1943,
#  'The Life and Death of Colonel Blimp': 1943,
#  'The Leopard Man': 1943,
#  'Meshes of the Afternoon': 1943,
#  'The Memphis Belle: A Story of a Flying Fortress': 1944,
#  'The More the Merrier': 1943,
#  'Phantom of the Opera': 1943,
#  'Report from the Aleutians': 1943,
#  'Saludos Amigos': 1942,
#  'The Seventh Victim': 1943,
#  'Shadow of a Doubt': 1943,
#  'So Proudly We Hail!': 1943,
#  'The Song of Bernadette': 1943,
#  'Stormy Weather': 1943,
#  'This Is the Army': 1943,
#  'Victory Through Air Power': 1943,
#  'Watch on the Rhine': 1943,
#  'The Battle of Russia': 1943,
#  'The Curse of the Cat People': 1944,
#  'Double Indemnity': 1944,
#  'The Fighting Lady': 1944,
#  'The Best Years of Our Lives': 1946,
#  'Gaslight': 1944,
#  'Going My Way': 1944,
#  'Hail the Conquering Hero': 1944,
#  'Torment': 1944,
#  'Laura': 1944,
#  'Lifeboat': 1944,
#  'Meet Me in St. Louis': 1944,
#  'Marèa Candelaria (Xochimilco)': 1944,
#  'Murder, My Sweet': 1944,
#  'None But the Lonely Heart': 1944,
#  'National Velvet': 1944,
#  'Since You Went Away': 1944,
#  'This Happy Breed': 1944,
#  'Thirty Seconds Over Tokyo': 1944,
#  'Tunisian Victory': 1944,
#  'The Way Ahead': 1944,
#  'And Then There Were None': 1945,
#  'The Body Snatcher': 1945,
#  'The Clock': 1945,
#  'Detour': 1945,
#  'Dead of Night': 1945,
#  'Domingo de carnaval': 1945,
#  "L'espoir": 1945,
#  'Children of Paradise': 1945,
#  'House of Dracula': 1945,
#  'The House on 92nd Street': 1945,
#  'Isle of the Dead': 1945,
#  'Leave Her to Heaven': 1945,
#  'The Last Chance': 1945,
#  'La perla': 1947,
#  'Rhapsody in Blue': 1945,
#  'Red Meadows': 1945,
#  'The Southerner': 1945,
#  'Story of G.I. Joe': 1945,
#  'A Song to Remember': 1945,
#  'State Fair': 1945,
#  'The Testimony': 1946,
#  'The Three Caballeros': 1944,
#  'A Tree Grows in Brooklyn': 1945,
#  'The Valley of Decision': 1945,
#  'Wonder Man': 1945,
#  'A Walk in the Sun': 1945,
#  'I See a Dark Stranger': 1946,
#  'Anna and the King of Siam': 1946,
#  'The Battle of the Rails': 1946,
#  'The Bandit': 1946,
#  'Bedlam': 1946,
#  'The Big Sleep': 1946,
#  'Caesar and Cleopatra': 1945,
#  'The Captive Heart': 1946,
#  'The Chase': 1946,
#  'Devil in the Flesh': 1947,
#  'The Diary of a Chambermaid': 1946,
#  'Enamorada': 1946,
#  "It's a Wonderful Life": 1946,
#  'The Jolson Story': 1946,
#  'Let There Be Light': 1946,
#  'Levoton veri': 1946,
#  'Make Mine Music': 1946,
#  'Stairway to Heaven': 1946,
#  'My Darling Clementine': 1946,
#  'Murderers Among Us': 1946,
#  'Muzi bez krèdel': 1946,
#  'Notorious': 1946,
#  'Panic': 1946,
#  'La porta del cielo': 1945,
#  "The Razor's Edge": 1946,
#  'Rome, Open City': 1945,
#  'The Seventh Veil': 1945,
#  'Sister Kenny': 1946,
#  'Song of the South': 1946,
#  'The Stranger': 1946,
#  'Pastoral Symphony': 1946,
#  'To Each His Own': 1946,
#  'The Yearling': 1946,
#  'Ziegfeld Follies': 1945,
#  'The Eagle with Two Heads': 1948,
#  'The Ball at the Anjo House': 1947,
#  'Body and Soul': 1947,
#  'Boomerang!': 1947,
#  'Bowery Buckaroos': 1947,
#  'The Cat Concerto': 1947,
#  'Dreams That Money Can Buy': 1947,
#  "Dèdèe d'Anvers": 1948,
#  'A Double Life': 1947,
#  "Gentleman's Agreement": 1947,
#  'The Fugitive': 1947,
#  'Lost Youth': 1948,
#  'Green Dolphin Street': 1947,
#  'Hungry Hill': 1947,
#  'It Happened on Fifth Avenue': 1947,
#  'Kiss of Death': 1947,
#  'The Damned': 1947,
#  'Mine Own Executioner': 1947,
#  'Mother Wore Tights': 1947,
#  'Miracle on 34th Street': 1947,
#  'Monsieur Vincent': 1947,
#  'Mourning Becomes Electra': 1947,
#  'La nao capitana': 1947,
#  'Possessed': 1947,
#  'Angelina': 1947,
#  'Quai des Orfèvres': 1947,
#  'Symphony of Life': 1948,
#  'The Sin of Harold Diddlebock': 1947,
#  'One Wonderful Sunday': 1947,
#  'I Became a Criminal': 1947,
#  'An Act of Murder': 1948,
#  "L'amore": 1948,
#  'All My Sons': 1948,
#  'Bud Abbott Lou Costello Meet Frankenstein': 1948,
#  "Angels' Alley": 1948,
#  'Apartment for Peggy': 1948,
#  'Anni difficili': 1948,
#  'Berlin Express': 1948,
#  'The Big Clock': 1948,
#  'Call Northside 777': 1948,
#  'Command Decision': 1948,
#  'Cry of the City': 1948,
#  'Easter Parade': 1948,
#  'The Emperor Waltz': 1948,
#  'Quartet': 1948,
#  'Every Girl Should Be Married': 1948,
#  'Force of Evil': 1948,
#  'A Foreign Affair': 1948,
#  'Fort Apache': 1948,
#  'He Walked by Night': 1948,
#  'I Remember Mama': 1948,
#  'June Bride': 1948,
#  'A Hen in the Wind': 1948,
#  'Louisiana Story': 1948,
#  'Macbeth': 1948,
#  'The Mating of Millie': 1948,
#  'La mies es mucha': 1948,
#  'Melody Time': 1948,
#  'Mr. Blandings Builds His Dream House': 1948,
#  'The Naked City': 1948,
#  'The Paleface': 1948,
#  'The Pirate': 1948,
#  'Red River': 1948,
#  'Portrait of Jennie': 1948,
#  'Rope': 1948,
#  'Road House': 1948,
#  'Without Pity': 1948,
#  'The Search': 1948,
#  'Sitting Pretty': 1948,
#  'The Snake Pit': 1948,
#  'Sorry, Wrong Number': 1948,
#  'Station West': 1948,
#  'The Street with No Name': 1948,
#  'That Lady in Ermine': 1948,
#  'La Terra Trema': 1948,
#  'To the Ends of the Earth': 1948,
#  'The Winslow Boy': 1948,
#  'Yellow Sky': 1948,
#  'You Were Meant for Me': 1948,
#  'Yoru no onnatachi': 1948,
#  'Act of Violence': 1948,
#  'Neecha Nagar': 1946,
#  'èA volar joven!': 1947,
#  'Divide and Conquer': 1943,
#  'The Battle of Britain': 1943,
#  'War Comes to America': 1945,
#  'The Battle of China': 1944,
#  'The Nazis Strike': 1943,
#  'Ornamental Hairpin': 1941}

# %% [markdown]
# ### Упражнение 2. Конвейер агрегации

# %% [markdown]
# #### Задача 2.1 — **3 балла**

# %% [markdown]
# В рамках этой задачи требуется узнать, какие фильмы получили наибольшее число комментариев. Составьте для этого конвейер агрегации с перечисленными ниже этапами. Для удобства рекомендуется воспользоваться приложением Compass.
#
# 1. Сгруппировать документы коллекции `comments` по полю `movie_id` и подсчитать количество комментариев для каждого фильма, записав его в поле `count`.
# 1. Отсортировать получившийся набор данных по убыванию количества комментариев (так чтобы первый документ в этом наборе указывал на фильм с наибольшим количеством комментариев).
# 1. Используя оператор `$lookup`, присоединить коллекцию `movies` (по полю `movie_id`).
# 1. Выполнить проекцию, оставив в наборе данных только три поля: название фильма (`title`), год выпуска (`year`) и количество комментариев (поле `count`, добавленное на первом этапе). Для этого воспользуйтесь оператором `$project`: https://www.mongodb.com/docs/manual/reference/operator/aggregation/project/. Обратите внимание, что данные из коллекции `movies` (`title` и `year`) на этом этапе окажутся внутри массива.
# 1. Применить оператор `$unwind`, чтобы деконструировать этот массив. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/. В результате массив должен превратиться в одиночный объект.
# 1. Применить оператор `$addFields`, чтобы добавить поля `title` и `year` на вернхий уровень структуры документа. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/addFields/.
# 1. Еще раз выполнить проекцию, чтобы удалить поле с массивом.
#
# Ваш алгоритм решения может отличаться от приведенного здесь. Главное — достичь цели: получить плоский набор данных с тремя полями (`count` — количество комментариев, `year` — год выпуска, `title` — название фильма).
#
# Скопируйте полученный конвейер в этот документ в виде кода на Python и выведите его на экран в виде списка словарей.

# %%
# Ваш код здесь

# %% [markdown]
# #### Задача 2.2 — **1 балл**

# %% [markdown]
# Используя данные, полученные в задаче 2.1, выведите на экран столбчатую диаграмму, показывающую топ-20 наиболее комментируемых фильмов. По оси ординат выведите названия этих фильмов (подписи разместите слева диаграммы), по оси абсцисс — количество комментариев.
#
# Для решения задачи можно использовать любую библиотеку, например Seaborn или Matplotlib.

# %%
# Ваш код здесь
